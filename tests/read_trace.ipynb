# %%
import pandas as pd
import pickle

# %%
# Replace 'file.pkl' with your filename
with open('mytrace.pickle', 'rb') as f:
    mytrace = pickle.load(f)

# %%
df1 = pd.DataFrame(mytrace[0][0], 
                   # columns=names
                  )  # samples from prior

# %%
df1
# Out:
#             0         1
# 0    1.118716  0.604808
# 1    0.833902  1.085541
# 2    2.006823  0.637469
# 3    1.253362  0.860574
# 4    1.457948  0.978516
# ..        ...       ...
# 495  1.351728  1.082545
# 496  0.923121  1.155041
# 497  1.180035  0.541703
# 498  1.213776  0.950779
# 499  1.741157  0.479162
#
# [500 rows x 2 columns]

# %%
type(mytrace)
# Out:
# list

# %%
len(mytrace)
# Out:
# 11

# %%
len(mytrace[0])
# Out:
# 6
