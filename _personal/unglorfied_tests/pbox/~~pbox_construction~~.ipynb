# %% [markdown]
# # Introduction
#
# Probability Bounds Analysis Solves the Problem of Incomplete Specification. This file will demonstrate serveral situations of incomplete specification where p-boxes can be constructed.

# %% [markdown]
# ### partial distribution information
#
# Nonparametric pboxes will be instantiated.

# %% [markdown]
# ### partial moment information (missing family)
#
#
# ![image.png](attachment:047d69bc-fbef-4ff3-bcef-432dba1c2480.png)
#
# ![image.png](attachment:62b054ca-70cd-4dc3-9f1f-ae76d6ea513b.png)
#
# Above are some examples from the papers of Matthias but in fact Scott had described more scenarios shown below:
#
# ![image.png](attachment:a1ea8b65-adce-4a55-b4af-fd75a64fd44f.png)
