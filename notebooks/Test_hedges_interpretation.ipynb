# %%
from pyuncertainnumber.nlp.language_parsing import *
from rich import print as rprint
import matplotlib.pyplot as plt
# from PyUncertainNumber.pba.params import *

# %%
# %load_ext autoreload
# %autoreload 2
# %load_ext rich
# %matplotlib inline

# %% [markdown]
# # helper module

# %%
def test_hedge_interpretation(input_numstr):
    """ a helper func to verify func 'hedge_interpretation """

    rprint(f"With the input '{input_numstr}':")
    rprint(f'we get: {hedge_interpret(input_numstr)}')

# %%
# def test_func(text):
#     splitted_list = text.split()
#     kwd = [s for s in splitted_list if not is_number(s)]
#     kwd = " ".join(kwd)
#     return kwd

# %% [markdown]
# # inputs

# %%
x1 = '7'
x2 = '7.0'
x3 = 'exactly 7'
x4 = 'about 7'
x5 = 'over 7'
x6 = 'at most 7'

# %% [markdown]
# # interval tests

# %%
test_hedge_interpretation(x1)

# %%
test_hedge_interpretation(x2)

# %%
test_hedge_interpretation(x3)

# %%
test_hedge_interpretation(x4)

# %%
test_hedge_interpretation(x5)

# %%
test_hedge_interpretation(x6)

# %%
test_hedge_interpretation("about 200")

# %%
# test check that input hedge must be a string
hedge_interpret(7)

# %% [markdown]
# ### top-level API test

# %%
from PyUncertainNumber.pba.intervalOperators import parse_bounds

# %%
for x in [x1,x2,x3,x4,x5,x6]:
    print(parse_bounds(x))

# %%
parse_bounds(x4)

# %% [markdown]
# # pbox tests

# %%
h = hedge_interpret('about 200', return_type='pbox')

# %%
_ = h.display(title='about 200')
plt.xlim([170, 230])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (170.0, 230.0)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 640x480 with 1 Axes>

# %%
fig, axs = plt.subplots(nrows=2, ncols=2, figsize=(10, 10), layout="constrained", sharex=True, sharey=True)
_ = hedge_interpret('about 200', return_type='pbox').display(ax=axs[0, 0], title='about 200')
_ = hedge_interpret('around 200', return_type='pbox').display(ax=axs[0, 1], title='around 200')
_ = hedge_interpret('approximately 200', return_type='pbox').display(ax=axs[1, 0], title='approximately 200')
_ = hedge_interpret('exactly 200', return_type='pbox').display(ax=axs[1, 1], title='exactly 200')
plt.xlim([170, 230])
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (170.0, 230.0)
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x1000 with 4 Axes>

# %% [markdown]
# # test finding significant figures (digits)

# %%
a = '0.0034'

# %%
b = '0.0560'

# %%
count_sigfigs(a)

# %%
count_sigfigs(b)
